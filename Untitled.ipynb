# %%
#This Notedbook is for my IBM Data Science Professional Certificate Capstone Final Project

# %%
# !pip install pandas
# Out:
# ...
# WARNING: You are using pip version 20.1.1; however, version 21.0.1 is available.
# You should consider upgrading via the 'c:\users\samsung\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
import numpy as np

# %%
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
